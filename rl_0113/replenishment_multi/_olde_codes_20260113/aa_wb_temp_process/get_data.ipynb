# %%
import pandas as pd

df = pd.read_parquet("/Users/weibin/Desktop/weibin_projects/replenishment/data/vn_2000sku.parquet")
# df = df[df['date']<=47]
print(max(df['date']))
# Out:
# 47

# %%
print(max(df['date']))
df.to_parquet("/Users/weibin/Desktop/weibin_projects/replenishment/data/vn_2000sku.parquet")
# Out:
# 47
