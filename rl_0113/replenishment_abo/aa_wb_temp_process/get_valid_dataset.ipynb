# %%
import pandas as pd
origin_path = "/home/work/apb-project/ais-deploy-demo-cache/replenishment_wb/replenishment_ppo/data/20250730/0730_test_new_100k"
df = pd.read_parquet(origin_path)

# %%
# 取第一条数据的idx
first_idx = df['idx'].sample(n=21, random_state=42)

# 只保留该idx的数据
one_sku_df = df[df['idx'].isin(first_idx)]
save_path = "/home/work/apb-project/ais-deploy-demo-cache/replenishment_wb/replenishment_ppo/data/20250730/0730_valid_one_sku"
one_sku_df.to_parquet(save_path)
